# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# #### Volodymyr Hlavnyi

# %% [markdown]
# Python Developer

# %% [markdown]
# ###### I am interested in data science because its very interesting...

# %% [markdown]
# ### Calc Gauss formula

# %%
def gauss(n):
    return (n*(n+1))/2

gauss(100) == sum(range(101))

print(gauss(100))
# Out:
# 5050.0

# %% [markdown]
# * list 1
# * list 2
# * list 3
#
# Simple link to site [GitHub Pages](https://pages.github.com/)
#
# Some basic Git commands are:
# ```
# git status
# git add
# git commit
# ```
#
# > Simple text that is a quote
